# %% [markdown]
# <h1 style="text-align:center">Build Non-Linear Models Part 1</h1>
# <h2 style="text-align:center">Applied Question 8</h2>
# <p style="text-align:center">Robert Evans</p>
# <p style="text-align:center">School of Technology & Engineering, National University</p>
# <p style="text-align:center">DDS-8555: Predictive Analysis</p>
# <p style="text-align:center">Dr. Mohammad Yavarimanesh</p>
# <p style="text-align:center">January 26, 2025</p>

# %% [markdown]
# ## Part A

# %%
import numpy as np

# %%
# set seed for repeatability
np.random.seed(42)

# %%
# Generate predictor X and noise vector epsilon
n = 100
X = np.random.normal(size=n)
epsilon = np.random.normal(size=n)

# %% [markdown]
# ## Part B

# %%
# Define coefficients
beta_0 = 2.0
beta_1 = 1.5
beta_2 = -0.5
beta_3 = 0.3

# %%
# Generate response vector Y
Y =  beta_0 + beta_1 * X + beta_2 * X**2 + beta_3 * X**3 + epsilon

# %% [markdown]
# ## Part C

# %%
import statsmodels.api as sm
import pandas as pd

# %%
# Create a DataFrame with predictors X, X^2, ..., X^10
data = np.column_stack([X**i for i in range(1, 11)])
data = sm.add_constant(data)  # Add constant term for intercept

# %%
# Perform forward stepwise selection
def forward_stepwise_selection(data, Y):
    initial_features = []
    remaining_features = list(range(1, data.shape[1]))
    selected_features = initial_features[:]
    current_score, best_new_score = float('inf'), float('inf')
    
    while remaining_features and current_score == best_new_score:
        scores_with_candidates = []
        for candidate in remaining_features:
            features_to_test = selected_features + [candidate]
            model = sm.OLS(Y, data[:, features_to_test]).fit()
            score = model.aic
            scores_with_candidates.append((score, candidate))
        
        scores_with_candidates.sort()
        best_new_score, best_candidate = scores_with_candidates[0]
        
        if current_score > best_new_score:
            remaining_features.remove(best_candidate)
            selected_features.append(best_candidate)
            current_score = best_new_score
    
    return selected_features

selected_features = forward_stepwise_selection(data, Y)
print("Selected features:", selected_features)

# Fit the final model with selected features and print the summary
final_model = sm.OLS(Y, data[:, selected_features]).fit()
print(final_model.summary())
# Out:
# Selected features: [1, 3, 2, 4, 6, 8, 10]
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      y   R-squared (uncentered):                   0.782
# Model:                            OLS   Adj. R-squared (uncentered):              0.765
# Method:                 Least Squares   F-statistic:                              47.61
# Date:                Sun, 26 Jan 2025   Prob (F-statistic):                    4.79e-28
# Time:                        20:15:59   Log-Likelihood:                         -165.57
# No. Observations:                 100   AIC:                                      345.1
# Df Residuals:                      93   BIC:                                      363.4
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             1.4137      0.327      4.319      0.000       0.764       2.064
# x2             0.2949      0.162      1.822      0.072      -0.027       0.616
# x3             8.8150      1.296      6.803      0.000       6.242      11.388
# x4           -10.8676      2.541     -4.278      0.000     -15.913      -5.822
# x5             4.9622      1.577      3.147      0.002       1.831       8.093
# x6            -0.9411      0.370     -2.546      0.013      -1.675      -0.207
# x7             0.0613      0.028      2.217      0.029       0.006       0.116
# ==============================================================================
# Omnibus:                        2.585   Durbin-Watson:                   1.805
# Prob(Omnibus):                  0.275   Jarque-Bera (JB):                2.313
# Skew:                           0.372   Prob(JB):                        0.315
# Kurtosis:                       2.998   Cond. No.                     3.82e+04
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The condition number is large, 3.82e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ## Part D

# %%
# Create a DataFrame with predictors X, X^2, ..., X^10
data = np.column_stack([X**i for i in range(1, 11)])
data = sm.add_constant(data)  # Add constant term for intercept

# Perform backward stepwise selection
def backward_stepwise_selection(data, Y):
    initial_features = list(range(data.shape[1]))
    selected_features = initial_features[:]
    current_score, best_new_score = float('inf'), float('inf')
    
    while selected_features and current_score == best_new_score:
        scores_with_candidates = []
        for candidate in selected_features:
            features_to_test = list(selected_features)
            features_to_test.remove(candidate)
            model = sm.OLS(Y, data[:, features_to_test]).fit()
            score = model.aic
            scores_with_candidates.append((score, candidate))
        
        scores_with_candidates.sort()
        best_new_score, worst_candidate = scores_with_candidates[0]
        
        if current_score > best_new_score:
            selected_features.remove(worst_candidate)
            current_score = best_new_score
    
    return selected_features

selected_features = backward_stepwise_selection(data, Y)
print("Selected features:", selected_features)

# Fit the final model with selected features and print the summary
final_model = sm.OLS(Y, data[:, selected_features]).fit()
print(final_model.summary())
# Out:
# Selected features: [0, 1, 3, 6, 8, 10]
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.856
# Model:                            OLS   Adj. R-squared:                  0.849
# Method:                 Least Squares   F-statistic:                     112.0
# Date:                Sun, 26 Jan 2025   Prob (F-statistic):           5.06e-38
# Time:                        20:22:30   Log-Likelihood:                -130.78
# No. Observations:                 100   AIC:                             273.6
# Df Residuals:                      94   BIC:                             289.2
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.8018      0.107     16.782      0.000       1.589       2.015
# x1             1.4645      0.228      6.416      0.000       1.011       1.918
# x2             0.2890      0.111      2.603      0.011       0.069       0.509
# x3            -0.2440      0.098     -2.486      0.015      -0.439      -0.049
# x4             0.0963      0.043      2.239      0.028       0.011       0.182
# x5            -0.0091      0.004     -2.170      0.033      -0.017      -0.001
# ==============================================================================
# Omnibus:                        1.051   Durbin-Watson:                   2.187
# Prob(Omnibus):                  0.591   Jarque-Bera (JB):                1.066
# Skew:                           0.127   Prob(JB):                        0.587
# Kurtosis:                       2.563   Cond. No.                     4.19e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.19e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ## Part E

# %%
import matplotlib.pyplot as plt
from sklearn.linear_model import LassoCV

# %%
# Assuming X and Y are your predictors and response variable
# Generate polynomial features for X^1, X^2, ..., X^10
X_poly = np.column_stack([X**i for i in range(1, 11)])

# Fit a Lasso model using cross-validation to select optimal lambda (alpha)
lasso = LassoCV(cv=10)
lasso.fit(X_poly, Y)

# Plot cross-validation error as a function of lambda (alpha)
plt.figure(figsize=(8, 6))
plt.plot(lasso.alphas_, lasso.mse_path_, linestyle='-', color='blue', alpha=0.7)
plt.axvline(x=lasso.alpha_, color='red', linestyle='--', label='Optimal λ')
plt.xscale('log')
plt.xlabel('λ (Log scale)')
plt.ylabel('Mean Squared Error (MSE)')
plt.title('Cross-validation Error vs. λ for Lasso Regression')
plt.legend()
plt.show()

# Print the optimal lambda value
print(f"Optimal λ: {lasso.alpha_}")
# Report the resulting coefficient estimates
print("\nLasso Coefficient Estimates:")
for i, coef in enumerate(lasso.coef_):
    print(f"X^{i+1}: {coef}")
# Out:
# C:\Users\Robert Evans\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.08822156126132086, tolerance: 0.052091778534987976
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Robert Evans\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.33542782630956935, tolerance: 0.052091778534987976
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Robert Evans\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.19132293181820614, tolerance: 0.052091778534987976
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Robert Evans\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.4420836060209581, tolerance: 0.052091778534987976
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Robert Evans\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.5375228479580869, tolerance: 0.052091778534987976
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Robert Evans\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.48667754826630016, tolerance: 0.052091778534987976
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Robert Evans\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.3087383945755846, tolerance: 0.052091778534987976
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Robert Evans\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.051931700378986534, tolerance: 0.04997613168098016
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Robert Evans\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.16588440261367055, tolerance: 0.04997613168098016
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Robert Evans\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.17232767863760046, tolerance: 0.04997613168098016
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Robert Evans\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.3522562629734409, tolerance: 0.04997613168098016
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Robert Evans\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.3748783280805128, tolerance: 0.04997613168098016
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Robert Evans\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.15403383043857843, tolerance: 0.04997613168098016
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Robert Evans\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.2043582633129404, tolerance: 0.04997613168098016
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Robert Evans\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.4772551661367288, tolerance: 0.04971809795521905
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Robert Evans\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.29392201648664695, tolerance: 0.04971809795521905
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Robert Evans\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.49457320268436433, tolerance: 0.04971809795521905
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Robert Evans\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.5435306137881639, tolerance: 0.04971809795521905
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Robert Evans\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.4593574514663601, tolerance: 0.04971809795521905
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Robert Evans\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.2670553337485444, tolerance: 0.04971809795521905
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Robert Evans\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.07507008768448031, tolerance: 0.048437668027259004
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Robert Evans\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.11429875994178929, tolerance: 0.048437668027259004
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Robert Evans\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.13757326085590194, tolerance: 0.048437668027259004
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Robert Evans\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.15383286690314435, tolerance: 0.048437668027259004
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Robert Evans\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.16565347218494253, tolerance: 0.048437668027259004
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Robert Evans\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.1740470339460103, tolerance: 0.048437668027259004
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Robert Evans\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.17963955597576842, tolerance: 0.048437668027259004
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Robert Evans\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.18292058681475964, tolerance: 0.048437668027259004
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Robert Evans\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.18429961906019798, tolerance: 0.048437668027259004
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Robert Evans\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.18412408083327136, tolerance: 0.048437668027259004
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Robert Evans\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.18268917675518992, tolerance: 0.048437668027259004
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Robert Evans\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.1802453677105973, tolerance: 0.048437668027259004
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Robert Evans\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.17700465921893738, tolerance: 0.048437668027259004
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Robert Evans\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.17314600979486272, tolerance: 0.048437668027259004
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Robert Evans\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.16882000266735986, tolerance: 0.048437668027259004
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Robert Evans\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.16415288285190854, tolerance: 0.048437668027259004
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Robert Evans\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.1592500464429918, tolerance: 0.048437668027259004
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Robert Evans\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.15419905239858167, tolerance: 0.048437668027259004
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Robert Evans\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.14907222338871406, tolerance: 0.048437668027259004
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Robert Evans\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.1439288877114393, tolerance: 0.048437668027259004
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Robert Evans\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.1388173138815887, tolerance: 0.048437668027259004
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Robert Evans\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.13377637483182525, tolerance: 0.048437668027259004
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Robert Evans\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.13659660031819953, tolerance: 0.048437668027259004
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Robert Evans\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.20122649845720275, tolerance: 0.048437668027259004
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Robert Evans\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.12808184837348335, tolerance: 0.048437668027259004
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Robert Evans\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.49191210024787324, tolerance: 0.048437668027259004
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Robert Evans\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.7379811438830188, tolerance: 0.048437668027259004
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Robert Evans\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.8895988466678659, tolerance: 0.048437668027259004
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Robert Evans\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.968440106308492, tolerance: 0.048437668027259004
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Robert Evans\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.993231642063165, tolerance: 0.048437668027259004
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Robert Evans\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.9793995495782326, tolerance: 0.048437668027259004
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Robert Evans\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.9392124648068148, tolerance: 0.048437668027259004
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Robert Evans\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.8821509667033638, tolerance: 0.048437668027259004
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Robert Evans\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.8153525129156094, tolerance: 0.048437668027259004
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Robert Evans\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.4977915151811203, tolerance: 0.05069281452979995
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Robert Evans\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.3051607844460875, tolerance: 0.05069281452979995
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Robert Evans\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.4613939276186443, tolerance: 0.05069281452979995
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Robert Evans\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.45267551023516717, tolerance: 0.05069281452979995
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Robert Evans\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.17108282819035026, tolerance: 0.05069281452979995
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Robert Evans\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1.9187176835119146, tolerance: 0.05069281452979995
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Robert Evans\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.3212773185337028, tolerance: 0.05352676509045742
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Robert Evans\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.17117234783125923, tolerance: 0.05352676509045742
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Robert Evans\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.4541725121158606, tolerance: 0.05352676509045742
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Robert Evans\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.5415857763843519, tolerance: 0.05352676509045742
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Robert Evans\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.45467272278091286, tolerance: 0.05352676509045742
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Robert Evans\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.1411701045386735, tolerance: 0.05352676509045742
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Robert Evans\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.346927182306729, tolerance: 0.05352676509045742
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Robert Evans\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6.328641522361266, tolerance: 0.05352676509045742
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Robert Evans\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.5884147114944938, tolerance: 0.05078628779999357
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Robert Evans\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.3698603559122944, tolerance: 0.05078628779999357
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Robert Evans\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.536489237395017, tolerance: 0.05078628779999357
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Robert Evans\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.5383725873251706, tolerance: 0.05078628779999357
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Robert Evans\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.4002953554581552, tolerance: 0.05078628779999357
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Robert Evans\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.15242918458193344, tolerance: 0.05078628779999357
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Robert Evans\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.8356481635843238, tolerance: 0.05078628779999357
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Robert Evans\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.5989290984662148, tolerance: 0.05434567147623404
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Robert Evans\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.3862831517930658, tolerance: 0.05434567147623404
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Robert Evans\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.5467781236135636, tolerance: 0.05434567147623404
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Robert Evans\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.5206463888233657, tolerance: 0.05434567147623404
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Robert Evans\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.333944989196425, tolerance: 0.05434567147623404
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Robert Evans\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2.0620128541777945, tolerance: 0.05434567147623404
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Robert Evans\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6.20521104335279, tolerance: 0.05434567147623404
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Robert Evans\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.40324500270708086, tolerance: 0.05350273643282973
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Robert Evans\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.3042352279307181, tolerance: 0.05350273643282973
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Robert Evans\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.5041871129492392, tolerance: 0.05350273643282973
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Robert Evans\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.5247013484141121, tolerance: 0.05350273643282973
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Robert Evans\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.3910014285921761, tolerance: 0.05350273643282973
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Robert Evans\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.1346496483592432, tolerance: 0.05350273643282973
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Robert Evans\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 0.5193312232719904, tolerance: 0.05350273643282973
#   model = cd_fast.enet_coordinate_descent_gram(
# C:\Users\Robert Evans\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_coordinate_descent.py:683: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 3.9618850921031594, tolerance: 0.05350273643282973
#   model = cd_fast.enet_coordinate_descent_gram(
# Optimal λ: 83.06482967366632
#
# Lasso Coefficient Estimates:
# X^1: 0.0
# X^2: -0.0
# X^3: 0.0
# X^4: -0.0
# X^5: 0.0
# X^6: -0.0
# X^7: 0.0
# X^8: -0.0
# X^9: 0.00013926095594957226
# X^10: -0.0007430208943168665
